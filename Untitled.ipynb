# %%
from pipeline.load import MyDataset, get_dataloader
from matplotlib import pyplot as plt
import numpy as np
import requests
import pandas as pd
import json
import os
import pdb

# %%
train_loader = get_dataloader()
# Out:
# Load test: False
# training_data
# training_data/images/*.jpg
# Filtering images already written.
# Dataset Loaded.

# %%
example = next(iter(train_loader))

# %%
i = 4
fig, ax = plt.subplots(ncols=2)
ax[0].imshow(np.transpose(example[0][i], (1,2,0)))
ax[1].imshow(example[1][i].squeeze())
